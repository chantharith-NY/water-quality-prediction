# %% [markdown]
# # Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('D:\\Programming_data\\ITC_AMS\\Programming\\DataScience-project\\data-science-project\\data\\Clean data\\cleaned_data_January.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = pd.read_csv('D:\\Programming_data\\ITC_AMS\\Programming\\DataScience-project\\data-science-project\\data\\Clean data\\cleaned_data_January.csv')
#
# ...

# %% [markdown]
# ##  Display basic information about the data

# %%
print(data.info())
print(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59790 entries, 0 to 59789
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Index                   59790 non-null  int64
#  1   pH                      59790 non-null  float64
#  2   Iron                    59790 non-null  float64
#  3   Nitrate                 59790 non-null  float64
#  4   Chloride                59790 non-null  float64
#  5   Lead                    59790 non-null  float64
#  6   Zinc                    59790 non-null  float64
#  7   Color                   59790 non-null  int64
#  8   Turbidity               59790 non-null  float64
#  9   Fluoride                59790 non-null  float64
#  10  Copper                  59790 non-null  float64
#  11  Odor                    59790 non-null  float64
#  12  Sulfate                 59790 non-null  float64
#  13  Conductivity            59790 non-null  float64
# ...

# %% [markdown]
# ## Check for missing values

# %%
missing_values = data.isnull().sum()
print("Missing values:\n", missing_values)
# Out:
# Missing values:
#  Index                     0
# pH                        0
# Iron                      0
# Nitrate                   0
# Chloride                  0
# Lead                      0
# Zinc                      0
# Color                     0
# Turbidity                 0
# Fluoride                  0
# Copper                    0
# Odor                      0
# Sulfate                   0
# Conductivity              0
# Chlorine                  0
# Manganese                 0
# Total Dissolved Solids    0
# Source                    0
# Water Temperature         0
# Air Temperature           0
# Month                     0
# Day                       0
# Time of Day               0
# Target                    0
# dtype: int64

# %% [markdown]
# ## Plotting histograms for numerical columns

# %%
data.hist(bins=30, figsize=(15, 10))
plt.show()

# %% [markdown]
# ## Plotting box plots for numerical columns

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(data=data)
plt.show()

# %% [markdown]
# ## Plotting correlation matrix

# %%
# Exclude non-numeric columns
numeric_data = data.select_dtypes(include=[np.number])

plt.figure(figsize=(12, 8))
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# # Statistical Analysis

# %% [markdown]
# ## Calculating mean and standard deviation

# %%
mean_value = data['pH'].mean()
std_dev_value = data['pH'].std()
print(f"Mean: {mean_value}, Standard Deviation: {std_dev_value}")
# Out:
# Mean: 7.45515896939637, Standard Deviation: 0.8553539995307845

# %% [markdown]
# ## Hypothesis Testing

# %%
from scipy import stats
t_stat, p_value = stats.ttest_1samp(data['pH'], 0)
print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: 2131.205335761146, P-value: 0.0
