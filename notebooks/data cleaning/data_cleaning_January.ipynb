# %% [markdown]
# ## Cleaning January_data.xlsx

# %%
import pandas as pd

# %%
df = pd.read_excel("/Users/nychanthrith/data-science-project/data/January_data.xlsx")

# %%
df
# Out:
#          Index        pH          Iron   Nitrate    Chloride           Lead  \
# 0            0  8.332988  8.350000e-05  8.605777  122.799772   3.710000e-52
# 1            2  5.443762  2.010586e-02  3.816994  230.995630   5.290000e-76
# 2            8  8.238149  8.080000e-10  3.192381  143.222718   1.840000e-57
# 3           42  7.431496  1.635646e-03  1.539861  149.921626  6.450000e-195
# 4           45  6.618013  2.240000e-07  1.046327  137.400933   2.440000e-81
# ...        ...       ...           ...       ...         ...            ...
# 88212  1048538  7.202941  4.600000e-06  6.698150  178.411473   2.730000e-73
# 88213  1048540  7.949245  4.640000e-08  2.394735  167.133580   4.160000e-93
# 88214  1048554  7.228452  7.080000e-13  6.643336  145.662056  4.110000e-139
# 88215  1048562  6.749023  2.860000e-07  5.431533  153.103341   1.130000e-69
# 88216  1048566  7.922532  1.910188e-02  2.239796  165.107143  6.280000e-131
#
# ...

# %%
df.isnull().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88217 entries, 0 to 88216
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Index                   88217 non-null  bool
#  1   pH                      88217 non-null  bool
#  2   Iron                    88217 non-null  bool
#  3   Nitrate                 88217 non-null  bool
#  4   Chloride                88217 non-null  bool
#  5   Lead                    88217 non-null  bool
#  6   Zinc                    88217 non-null  bool
#  7   Color                   88217 non-null  bool
#  8   Turbidity               88217 non-null  bool
#  9   Fluoride                88217 non-null  bool
#  10  Copper                  88217 non-null  bool
#  11  Odor                    88217 non-null  bool
#  12  Sulfate                 88217 non-null  bool
#  13  Conductivity            88217 non-null  bool
# ...

# %%
df.isnull().sum()
# Out:
# Index                        0
# pH                        1698
# Iron                       612
# Nitrate                   1578
# Chloride                  2615
# Lead                       405
# Zinc                      2280
# Color                       81
# Turbidity                  753
# Fluoride                  2872
# Copper                    2959
# Odor                      2690
# Sulfate                   2879
# Conductivity              2425
# Chlorine                   860
# Manganese                 1671
# Total Dissolved Solids      27
# Source                    1265
# Water Temperature         2522
# Air Temperature            468
# Month                        0
# Day                       1484
# Time of Day               1707
# Target                       0
# dtype: int64

# %%
df["pH"]
# Out:
# 0        8.332988
# 1        5.443762
# 2        8.238149
# 3        7.431496
# 4        6.618013
#            ...
# 88212    7.202941
# 88213    7.949245
# 88214    7.228452
# 88215    6.749023
# 88216    7.922532
# Name: pH, Length: 88217, dtype: float64

# %%
df["pH"].notnull()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 88212    True
# 88213    True
# 88214    True
# 88215    True
# 88216    True
# Name: pH, Length: 88217, dtype: bool

# %%
null_data = df[df["pH"].isnull()]

# %%
null_data
# Out:
#          Index  pH          Iron   Nitrate    Chloride           Lead  \
# 44         539 NaN  2.646770e-04  6.746861  246.210476   7.920000e-21
# 47         552 NaN  6.147040e-04  9.165009  128.712155  2.140000e-190
# 90        1172 NaN  6.960000e-07  6.175325  204.131470   4.370000e-96
# 104       1273 NaN  2.201114e-02  2.733084  204.995334  3.320000e-308
# 113       1364 NaN  5.865601e-03  7.591204  136.694140  4.620000e-150
# ...        ...  ..           ...       ...         ...            ...
# 87690  1042732 NaN  6.201853e-02  5.511418  198.785867   3.070000e-67
# 87699  1042809 NaN  6.440000e-05  7.313949   76.689216  6.970000e-238
# 88004  1046011 NaN  6.249987e-03  4.632648  178.076913   7.580000e-10
# 88105  1047181 NaN  2.018511e-01  4.568273  135.222494   5.220000e-40
# 88193  1048360 NaN  1.099714e-03  4.878426  166.353456   1.460000e-12
#
#            Zinc           Color  Turbidity  Fluoride  ...  Chlorine  \
# ...

# %%
cleaned_data = df.dropna()

# %%
cleaned_data
# Out:
#          Index        pH          Iron   Nitrate    Chloride           Lead  \
# 1            2  5.443762  2.010586e-02  3.816994  230.995630   5.290000e-76
# 5           52  8.460833  1.986337e-02  8.601511  134.202428  1.170000e-256
# 6           64  8.194406  3.387248e-03  8.344541  248.043661   2.410000e-71
# 8           90  5.812626  1.061910e-04  3.032464  199.084282  4.120000e-114
# 9          116  6.806017  2.458747e-01  6.685902   98.370632   2.420000e-90
# ...        ...       ...           ...       ...         ...            ...
# 88211  1048529  7.786804  2.044458e-01  4.537733  218.653193  2.670000e-198
# 88213  1048540  7.949245  4.640000e-08  2.394735  167.133580   4.160000e-93
# 88214  1048554  7.228452  7.080000e-13  6.643336  145.662056  4.110000e-139
# 88215  1048562  6.749023  2.860000e-07  5.431533  153.103341   1.130000e-69
# 88216  1048566  7.922532  1.910188e-02  2.239796  165.107143  6.280000e-131
#
# ...

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59790 entries, 1 to 88216
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Index                   59790 non-null  int64
#  1   pH                      59790 non-null  float64
#  2   Iron                    59790 non-null  float64
#  3   Nitrate                 59790 non-null  float64
#  4   Chloride                59790 non-null  float64
#  5   Lead                    59790 non-null  float64
#  6   Zinc                    59790 non-null  float64
#  7   Color                   59790 non-null  object
#  8   Turbidity               59790 non-null  float64
#  9   Fluoride                59790 non-null  float64
#  10  Copper                  59790 non-null  float64
#  11  Odor                    59790 non-null  float64
#  12  Sulfate                 59790 non-null  float64
#  13  Conductivity            59790 non-null  float64
# ...

# %%
cleaned_data["Source"]
# Out:
# 1          River
# 5        Aquifer
# 6         Spring
# 8         Ground
# 9          River
#           ...
# 88211     Spring
# 88213     Stream
# 88214      River
# 88215     Spring
# 88216       Lake
# Name: Source, Length: 59790, dtype: object

# %%
import matplotlib.pyplot as plt

unique_counts = df.nunique()
unique_counts.plot(kind='bar', color='skyblue')
plt.title("Unique Values per Column")
plt.ylabel("Count")
plt.xlabel("Columns")
plt.show()

# %%
unique_cities = cleaned_data["Source"].unique()

# %%
unique_cities
# Out:
# array(['River', 'Aquifer', 'Spring', 'Ground', 'Well', 'Stream',
#        'Reservoir', 'Lake'], dtype=object)

# %%
river_data = cleaned_data[cleaned_data["Source"] == "River"]

# %%
river_data[river_data["Target"]==0]
# Out:
#          Index        pH          Iron   Nitrate    Chloride           Lead  \
# 1            2  5.443762  2.010586e-02  3.816994  230.995630   5.290000e-76
# 9          116  6.806017  2.458747e-01  6.685902   98.370632   2.420000e-90
# 18         250  8.194909  1.164868e-01  4.695976   63.010549   1.190000e-50
# 28         343  9.644315  2.007252e-02  3.106384  177.762030   6.470000e-61
# 33         441  6.667077  3.340000e-19  4.361460  230.393086   1.300000e-54
# ...        ...       ...           ...       ...         ...            ...
# 88132  1047535  7.692494  5.903460e-04  3.735610  195.550777   1.170000e-66
# 88183  1048226  6.892864  1.430000e-10  5.328375  231.157044  2.310000e-131
# 88184  1048234  8.084943  3.420000e-08  7.233986  173.832686   2.400000e-38
# 88191  1048316  7.561142  7.830000e-06  4.034245  230.157072  3.250000e-133
# 88214  1048554  7.228452  7.080000e-13  6.643336  145.662056  4.110000e-139
#
# ...

# %%
river_data_ph1=river_data[river_data["Target"]==1]

# %%
river_data
# Out:
#          Index        pH          Iron   Nitrate    Chloride           Lead  \
# 1            2  5.443762  2.010586e-02  3.816994  230.995630   5.290000e-76
# 9          116  6.806017  2.458747e-01  6.685902   98.370632   2.420000e-90
# 18         250  8.194909  1.164868e-01  4.695976   63.010549   1.190000e-50
# 28         343  9.644315  2.007252e-02  3.106384  177.762030   6.470000e-61
# 33         441  6.667077  3.340000e-19  4.361460  230.393086   1.300000e-54
# ...        ...       ...           ...       ...         ...            ...
# 88132  1047535  7.692494  5.903460e-04  3.735610  195.550777   1.170000e-66
# 88183  1048226  6.892864  1.430000e-10  5.328375  231.157044  2.310000e-131
# 88184  1048234  8.084943  3.420000e-08  7.233986  173.832686   2.400000e-38
# 88191  1048316  7.561142  7.830000e-06  4.034245  230.157072  3.250000e-133
# 88214  1048554  7.228452  7.080000e-13  6.643336  145.662056  4.110000e-139
#
# ...

# %%
sort_day=[river_data_ph1["Day"].sort_values()]

# %%
sort_day
# Out:
# [27270     1.0
#  27376     1.0
#  62842     1.0
#  27475     1.0
#  59837     1.0
#           ...
#  23321    31.0
#  23590    31.0
#  24155    31.0
#  22961    31.0
#  22723    31.0
#  Name: Day, Length: 1761, dtype: float64]
